# %% [markdown]
# # My First Jupyter Notebook
#
# My first markdown cell in Jupyter.
#
# This notebook was created for the GitHub and Jupyter exploration lab.

# %%
print("Hello, World!")
# Out:
# Hello, World!
